# %% [markdown]
# # **Building Intelligent Workflows with LangChain: A Practical Exploration**

# %% [markdown]
# ## **Exploring LangChain Concepts with a Free LLM**
#
# In this notebook, I explore how LangChain helps transform simple language models into structured and intelligent systems.
#
# Rather than treating AI as a black box, I focus on breaking it down step by step — starting from basic model interaction to building reusable workflows.
#
# To avoid dependency on paid APIs, I use an open-source model, which allows me to focus purely on understanding the core concepts of prompt design, chaining, and workflow creation.

# %%
# !pip install -q langchain transformers torch

# %% [markdown]
# ## **Importing Required Libraries**
#
# LangChain provides modular tools, and I am combining it with a transformer-based model.

# %%
from transformers import pipeline
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ## **Initializing the Language Model**
#
# Here, I am using a lightweight open-source model (GPT-2) to simulate LLM behavior.

# %%
llm = pipeline("text-generation", model="gpt2")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ## **Step 1: Basic LLM Interaction**
#
# Let me first observe how the model responds without any structured prompt.
#
# This helps in understanding how the model behaves without any structured input.

# %%
response = llm("Explain Artificial Intelligence in one simple sentence", max_length=50)
print(response[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence in one simple sentence and let it learn
#
# If you're not in the mood for math, this is very helpful for learning. It will make reading and writing less difficult.
#
# Don't want to know anything about Artificial Intelligence? Just read this book called The Nature of Intelligence.
#
# A second tool is Computer Vision.
#
# A third tool is Cognitive Learning.
#
# A fourth tool is Artificial Intelligence.
#
# And finally, a fifth tool is Artificial Intelligence for Business.
#
# If you want to learn more about all of these things, there are lots more resources available at:
#
# The Science of AI

# %% [markdown]
# ## **Step 2: Creating a Prompt Template**
#
# Instead of writing prompts manually every time, I can design reusable templates.

# %%
prompt = PromptTemplate.from_template(
    "Explain {topic} in a simple and beginner-friendly way"
)

formatted_prompt = prompt.format(topic="Machine Learning")
print(formatted_prompt)
# Out:
# Explain Machine Learning in a simple and beginner-friendly way

# %% [markdown]
# ## **Step 3: Building a Simple Pipeline**
#
# Here I combine the prompt template with the language model.
#
# This step connects the prompt and model, forming a basic workflow similar to LangChain pipelines.

# %%
final_prompt = prompt.format(topic="Neural Networks")

response = llm(final_prompt, max_length=60)
print(response[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Neural Networks in a simple and beginner-friendly way.
#
# As a general rule, the most important part of this tutorial is to get your brain to understand some basic concepts of neural networks. In particular, if you don't know any of the basic concepts in this tutorial, then you will have an easier time understanding what these are. This also means that the best way to learn these concepts is to use a brain scanner. If you don't know any of the basic concepts in this tutorial, then you will need to learn the basic concepts in this tutorial.
#
# How to learn Python Neural Networks
#
# If you haven't already done this tutorial, then you might want to skip it and read the first part.
#
# The first part of this tutorial is all about learning basic concepts. The rest of this tutorial is just about learning basic concepts.
#
# The second part of the tutorial is about developing neural networks. The other parts are about learning basic concepts using Python Neural Networks.
#
# Don't forget to check the sections on learning by using the Python Neural Network and Learning Deep Learning.
#
# If you don't know the basics in this tutorial and don't want to know the basic concepts, then you can skip the third part and skip the first part.
#
# Learn how Python Neural Networks work by learning

# %% [markdown]
# Note: In modern LangChain, pipelines are created using a chaining mechanism where prompts and models are combined. Here, I simulate the same idea manually using a prompt template and a language model.

# %% [markdown]
# ## **Step 4: Creating a Reusable Workflow**
#
# Now I extend the same pipeline to generate real-world use cases.

# %%
usecase_prompt = PromptTemplate.from_template(
    "Give 3 real-world applications of {topic}"
)

text = usecase_prompt.format(topic="Artificial Intelligence")

response = llm(text, max_length=80)
print(response[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Give 3 real-world applications of Artificial Intelligence, including AI and real-world problems.
#
# Learn how you can create real-world applications from real-world problems.
#
# Get a personalized, personalized experience with The Future Of Life
#
# Build personalized, personalized apps that help you find life the way you want to go — and help you be as productive as possible.
#
# We believe that our products will be the most meaningful tool for people to use.
#
# It's time to take a step back and think of a real-world application.
#
# Here are some of the major innovations from The Future Of Life team:
#
# Recharge your batteries with one of The Future Of Life's rechargeable rechargeable batteries.
#
# Make the smart phone your home in seconds.
#
# Create a smart, personalized website for a business, online store, or social networking site.
#
# Take your company to the next level by offering a unique experience, making it easy for you to do the same.
#
# Create and discover new ideas and solutions.
#
# Get to know your customers and your customers-to-be.
#
# Our partners at The Future Of Life can help you find your perfect customer.
#
# To learn more about The Future Of Life's products, visit TheFutureOfLife

# %% [markdown]
# ## **Step 5: Testing with Multiple Inputs**
#
# To make the system dynamic, I test multiple topics.

# %%
topics = ["Data Science", "Robotics", "Cyber Security"]

# Updated prompt (to avoid repetition and improve quality)
prompt = PromptTemplate.from_template(
    "Explain {topic} in a simple, clear and unique way with one real-world example"
)

for topic in topics:
    text = prompt.format(topic=topic)

    result = llm(
        text,
        max_length=80,
        num_return_sequences=1,
        do_sample=True,
        temperature=0.7,
        pad_token_id=50256,
        truncation=True
    )

    print(f"\n🔹 Topic: {topic}")
    print(result[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Topic: Data Science
# Explain Data Science in a simple, clear and unique way with one real-world example. Learn how to build your own web development framework.
#
# About the Author
#
# David F. Feltman is a CTO at Cauldron, an industry leader in the field of HTML, CSS and JavaScript. He writes about HTML, CSS and JavaScript in his own words. He is the author of The Web Dev Platform, a book written by Matt Schulz and published by Scribner. His most recent book, The Web Dev Platform: The Definitive Guide, has been published by Elsevier.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Topic: Robotics
# Explain Robotics in a simple, clear and unique way with one real-world example - a toy robot using a robotic arm. This model is being used to demonstrate what Artificial Intelligence can do. We are also going to demonstrate how we can build a robot with a simple, simple, simple and simple program. In this video, we present a robot that's able to read a list of items, navigate to a destination, and walk around the room. This robot is very intelligent, but it's also very simple and very easy to use.
#
# This video will explain all the major basic concepts of Robotics in a simple, clear and unique way with one real-world example - a toy robot using a robotic arm. This model is being used to demonstrate what Artificial Intelligence can do. We are also going to demonstrate how we can build a robot with a simple, simple, simple and simple program. In this video, we present a robot that's able to read a list of items, navigate to a destination, and walk around the room. This robot is very intelligent, but it's also very simple and very easy to use. Robotics in a short time
#
# This video will explain all the major basic concepts of Robotics in a simple, clear and unique way with one real-world example - a toy robot using a robotic arm. This model is being
#
# 🔹 Topic: Cyber Security
# Explain Cyber Security in a simple, clear and unique way with one real-world example for you to learn about.
#
# One of the things that keeps you busy while you're there is the fact that there is an ongoing battle for the hearts and minds of the world. You don't have to worry about what people think, you can just get it done and enjoy it for a few days.
#
# So go out and meet another new person and join them and see for yourself what a great idea they are.
#
# You want to know if they are right for you?
#
# This is the moment.
#
# Maybe they have some great ideas. Maybe they are good at it.
#
# But you don't know if it will work out?
#
# What can you do?
#
# You could simply follow them on Twitter or Facebook or wherever.
#
# You could do that every day, every day...
#
# All right, I don't know what I would do with all of this time, but I could use it.
#
# I have a friend who is so focused on his computer that he has been doing all of this and he is a computer nerd.
#
# He's actually been going to his computer for 15 years now, and he's not a computer geek but he's been doing this for 15 years.

# %% [markdown]
# ## **From these experiments, I observed:**
#
# - The structure of a prompt significantly influences the quality of output
# - Reusable templates make workflows more efficient and scalable
# - Even simple models can generate meaningful responses when guided properly
# - Breaking the system into steps improves both understanding and control
# - Open-source models like GPT-2 sometimes produce repetitive or less accurate outputs compared to advanced LLMs
#
# These observations highlight how LangChain focuses not just on models, but on designing structured AI workflows.

# %% [markdown]
# ## **Final Reflection**
#
# Through this notebook, I understood that:
#
# • LangChain is more about **how we structure AI workflows**
#
# • Prompt engineering plays a key role
#
# • Pipelines help in building scalable systems
#
# Even without paid APIs, the core ideas of LangChain can be clearly demonstrated.
#
# This experiment helped me understand that building AI systems is not just about using powerful models, but about designing the right workflow around them.

# %% [markdown]
# ## **What Makes This Approach Unique?**
#
# 🔹 API-Based Approach
# - Uses API-based models
# - Focus on direct understanding
# - Faster results but API dependent
#
# 🔹 My Approach:
# - Uses open-source model (no API dependency)
# - Focus on concept understanding
# - Demonstrates real workflow design
# - Easy to reproduce and extend
